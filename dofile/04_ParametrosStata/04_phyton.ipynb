# %% [markdown]
# # Parámetros causales: la misma demostración en Python
# Los resultados potenciales permanecen fijos. Solo cambia `D` cuando aleatorizamos.

# %%
import numpy as np
import pandas as pd

def build_observed(data):
    result = data.copy()
    result['tau'] = result['yd1'] - result['yd0']
    result['y'] = result['D'] * result['yd1'] + (1 - result['D']) * result['yd0']
    return result

def calculate_estimands(data):
    y1 = data.loc[data['D'].eq(1), 'y'].mean()
    y0 = data.loc[data['D'].eq(0), 'y'].mean()
    naive = y1 - y0
    att = data.loc[data['D'].eq(1), 'tau'].mean()
    return pd.Series({
        'ATE': data['tau'].mean(),
        'ATT': att,
        'ATU': data.loc[data['D'].eq(0), 'tau'].mean(),
        'CATE_X0': data.loc[data['X'].eq(0), 'tau'].mean(),
        'CATE_X1': data.loc[data['X'].eq(1), 'tau'].mean(),
        'NAIVE': naive,
        'SESGO_ATT': naive - att,
    })

# %% [markdown]
# ## 1. EJERCICIO MANUAL

# %%
data = pd.read_stata('04_data.dta', convert_categoricals=False)
data['D'] = data['D'].astype(int)
data['X'] = (np.arange(len(data)) >= 4).astype(int)
data = build_observed(data)
original = calculate_estimands(data)
display(data[['X', 'D', 'yd0', 'yd1', 'y', 'tau']])
display(original.to_frame('valor'))

# %% [markdown]
# ## 2. MISMA SELECCIÓN CON N = 80.000

# %%
data_n80000 = data.loc[data.index.repeat(10000)].reset_index(drop=True)
expanded = calculate_estimands(data_n80000)
assert len(data_n80000) == 80_000
np.testing.assert_allclose(expanded[['NAIVE', 'SESGO_ATT']], original[['NAIVE', 'SESGO_ATT']], atol=1e-12)
display(expanded.to_frame('valor'))

# %% [markdown]
# ## 3. UNA ASIGNACIÓN ALEATORIA

# %%
rng = np.random.default_rng(87634)
randomized = data_n80000.copy()
randomized['D'] = (rng.random(len(randomized)) < 0.5).astype(int)
randomized = build_observed(randomized)
display(calculate_estimands(randomized).to_frame('valor'))

# %% [markdown]
# ## 4. MONTE CARLO: UN D NUEVO EN CADA REPETICIÓN

# %%
rng = np.random.default_rng(87634)
n_repetitions = 1000
mc_estimators = np.empty(n_repetitions)
for repetition in range(n_repetitions):
    new_D = (rng.random(len(data_n80000)) < 0.5).astype(int)
    new_y = new_D * data_n80000['yd1'].to_numpy() + (1 - new_D) * data_n80000['yd0'].to_numpy()
    mc_estimators[repetition] = new_y[new_D == 1].mean() - new_y[new_D == 0].mean()

mc_se = mc_estimators.std(ddof=1) / np.sqrt(n_repetitions)
assert abs(mc_estimators.mean() - original['ATE']) < 3 * mc_se
pd.Series({
    'ATE': original['ATE'],
    'media_estimador': mc_estimators.mean(),
    'desviacion_estandar': mc_estimators.std(ddof=1),
    'error_estandar_media': mc_se,
    'repeticiones': n_repetitions,
})
